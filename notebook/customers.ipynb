# %%
import pandas as pd

# %%
import dtale
import pandas as pd

# %%
import dtale
import pandas as pd

df = pd.read_csv(r'D:\business-decision-intelligence-system\data\raw\customers.csv')

# %%
import sweetviz as sv
import pandas as pd

df = pd.read_csv(r'D:\business-decision-intelligence-system\data\raw\customers.csv')

report = sv.analyze(df)
report.show_html("customers_profiling.html")
